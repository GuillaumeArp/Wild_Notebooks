# %% [markdown]
# ## Imports

# %%
# !pip install plotly --upgrade
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (4.4.1)
# Collecting plotly
#   Downloading plotly-5.4.0-py2.py3-none-any.whl (25.3 MB)
#      |████████████████████████████████| 25.3 MB 62.2 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly) (1.15.0)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: tenacity, plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 4.4.1
#     Uninstalling plotly-4.4.1:
#       Successfully uninstalled plotly-4.4.1
# Successfully installed plotly-5.4.0 tenacity-8.0.1

# %%
import nltk
import pandas as pd
import plotly.express as px
import string
import spacy

# %%
nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/shakespeare.zip.
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/twitter_samples.zip.
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/omw.zip.
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet.zip.
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet31.zip.
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet_ic.zip.
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/words.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %%
## Source article: https://www.reuters.com/world/africa/safrica-says-it-is-being-punished-early-covid-variant-detection-2021-11-27/

article_text = '''
JOHANNESBURG, Nov 27 (Reuters) - South Africa said on Saturday it was being punished for its advanced ability to detect new COVID-19 variants early, as travel bans and restrictions imposed because of the new Omicron variant threaten to harm tourism and other sectors of the economy.

South Africa has some of the world's top epidemiologists and scientists, who have managed to detect emerging coronavirus variants and their mutations early on in their life cycle. The Omicron variant was first discovered in South Africa and has since been detected in Belgium, Botswana, Israel and Hong Kong.

"This latest round of travel bans is akin to punishing South Africa for its advanced genomic sequencing and the ability to detect new variants quicker," the Ministry of International Relations and Cooperation said.

"Excellent science should be applauded and not punished," it said in a statement.

Many nations rushed on Friday and Saturday to announce travel curbs to South Africa and other countries in the region.

The foreign ministry noted that while the new variant was also detected in other countries, the global reaction to those countries have been "starkly different" to cases in southern Africa.

The new variant was first announced on Wednesday by a team of scientists in South Africa who said they had detected a variant that could possibly evade the body's immune response and make it more transmissible.

On Friday the World Health Organization named it Omicron and designated it as a "variant of concern" - its most serious level - saying preliminary evidence suggests an increased risk of re-infection. read more

"Our immediate concern is the damage that these restrictions are causing to families, the travel and tourism industries and business," South African Foreign Minister Naledi Pandor said in the statement.

The government was engaging with countries that have imposed travel bans to persuade them to reconsider, it added.

On Friday, the WHO cautioned countries against hastily imposing travel restrictions linked to the variant, saying they should take a "risk-based and scientific approach".'''

# %% [markdown]
# ## Tokenization

# %%
sentence_tokens = nltk.sent_tokenize(article_text)
sentence_tokens
# Out:
# ['\nJOHANNESBURG, Nov 27 (Reuters) - South Africa said on Saturday it was being punished for its advanced ability to detect new COVID-19 variants early, as travel bans and restrictions imposed because of the new Omicron variant threaten to harm tourism and other sectors of the economy.',
#  "South Africa has some of the world's top epidemiologists and scientists, who have managed to detect emerging coronavirus variants and their mutations early on in their life cycle.",
#  'The Omicron variant was first discovered in South Africa and has since been detected in Belgium, Botswana, Israel and Hong Kong.',
#  '"This latest round of travel bans is akin to punishing South Africa for its advanced genomic sequencing and the ability to detect new variants quicker," the Ministry of International Relations and Cooperation said.',
#  '"Excellent science should be applauded and not punished," it said in a statement.',
#  'Many nations rushed on Friday and Saturday to announce travel curbs to South Africa and other countries in the region.',
#  'The foreign ministry noted that while the new variant was also detected in other countries, the global reaction to those countries have been "starkly different" to cases in southern Africa.',
#  "The new variant was first announced on Wednesday by a team of scientists in South Africa who said they had detected a variant that could possibly evade the body's immune response and make it more transmissible.",
#  'On Friday the World Health Organization named it Omicron and designated it as a "variant of concern" - its most serious level - saying preliminary evidence suggests an increased risk of re-infection.',
#  'read more\n\n"Our immediate concern is the damage that these restrictions are causing to families, the travel and tourism industries and business," South African Foreign Minister Naledi Pandor said in the statement.',
#  'The government was engaging with countries that have imposed travel bans to persuade them to reconsider, it added.',
#  'On Friday, the WHO cautioned countries against hastily imposing travel restrictions linked to the variant, saying they should take a "risk-based and scientific approach".']

# %%
word_tokens = nltk.word_tokenize(article_text.lower())
word_tokens
# Out:
# ['johannesburg',
#  ',',
#  'nov',
#  '27',
#  '(',
#  'reuters',
#  ')',
#  '-',
#  'south',
#  'africa',
#  'said',
#  'on',
#  'saturday',
#  'it',
#  'was',
#  'being',
#  'punished',
#  'for',
#  'its',
#  'advanced',
#  'ability',
#  'to',
#  'detect',
#  'new',
#  'covid-19',
#  'variants',
#  'early',
#  ',',
#  'as',
#  'travel',
#  'bans',
#  'and',
#  'restrictions',
#  'imposed',
#  'because',
#  'of',
#  'the',
#  'new',
#  'omicron',
#  'variant',
#  'threaten',
#  'to',
#  'harm',
#  'tourism',
#  'and',
#  'other',
#  'sectors',
#  'of',
#  'the',
#  'economy',
#  '.',
#  'south',
#  'africa',
#  'has',
#  'some',
#  'of',
#  'the',
#  'world',
#  "'s",
#  'top',
#  'epidemiologists',
#  'and',
#  'scientists',
#  ',',
#  'who',
#  'have',
#  'managed',
#  'to',
#  'detect',
#  'emerging',
#  'coronavirus',
#  'variants',
#  'and',
#  'their',
#  'mutations',
#  'early',
#  'on',
#  'in',
#  'their',
#  'life',
#  'cycle',
#  '.',
#  'the',
#  'omicron',
#  'variant',
#  'was',
#  'first',
#  'discovered',
#  'in',
#  'south',
#  'africa',
#  'and',
#  'has',
#  'since',
#  'been',
#  'detected',
#  'in',
#  'belgium',
#  ',',
#  'botswana',
#  ',',
#  'israel',
#  'and',
#  'hong',
#  'kong',
#  '.',
#  '``',
#  'this',
#  'latest',
#  'round',
#  'of',
#  'travel',
#  'bans',
#  'is',
#  'akin',
#  'to',
#  'punishing',
#  'south',
#  'africa',
#  'for',
#  'its',
#  'advanced',
#  'genomic',
#  'sequencing',
#  'and',
#  'the',
#  'ability',
#  'to',
#  'detect',
#  'new',
#  'variants',
#  'quicker',
#  ',',
#  "''",
#  'the',
#  'ministry',
#  'of',
#  'international',
#  'relations',
#  'and',
#  'cooperation',
#  'said',
#  '.',
#  '``',
#  'excellent',
#  'science',
#  'should',
#  'be',
#  'applauded',
#  'and',
#  'not',
#  'punished',
#  ',',
#  "''",
#  'it',
#  'said',
#  'in',
#  'a',
#  'statement',
#  '.',
#  'many',
#  'nations',
#  'rushed',
#  'on',
#  'friday',
#  'and',
#  'saturday',
#  'to',
#  'announce',
#  'travel',
#  'curbs',
#  'to',
#  'south',
#  'africa',
#  'and',
#  'other',
#  'countries',
#  'in',
#  'the',
#  'region',
#  '.',
#  'the',
#  'foreign',
#  'ministry',
#  'noted',
#  'that',
#  'while',
#  'the',
#  'new',
#  'variant',
#  'was',
#  'also',
#  'detected',
#  'in',
#  'other',
#  'countries',
#  ',',
#  'the',
#  'global',
#  'reaction',
#  'to',
#  'those',
#  'countries',
#  'have',
#  'been',
#  '``',
#  'starkly',
#  'different',
#  "''",
#  'to',
#  'cases',
#  'in',
#  'southern',
#  'africa',
#  '.',
#  'the',
#  'new',
#  'variant',
#  'was',
#  'first',
#  'announced',
#  'on',
#  'wednesday',
#  'by',
#  'a',
#  'team',
#  'of',
#  'scientists',
#  'in',
#  'south',
#  'africa',
#  'who',
#  'said',
#  'they',
#  'had',
#  'detected',
#  'a',
#  'variant',
#  'that',
#  'could',
#  'possibly',
#  'evade',
#  'the',
#  'body',
#  "'s",
#  'immune',
#  'response',
#  'and',
#  'make',
#  'it',
#  'more',
#  'transmissible',
#  '.',
#  'on',
#  'friday',
#  'the',
#  'world',
#  'health',
#  'organization',
#  'named',
#  'it',
#  'omicron',
#  'and',
#  'designated',
#  'it',
#  'as',
#  'a',
#  '``',
#  'variant',
#  'of',
#  'concern',
#  "''",
#  '-',
#  'its',
#  'most',
#  'serious',
#  'level',
#  '-',
#  'saying',
#  'preliminary',
#  'evidence',
#  'suggests',
#  'an',
#  'increased',
#  'risk',
#  'of',
#  're-infection',
#  '.',
#  'read',
#  'more',
#  "''",
#  'our',
#  'immediate',
#  'concern',
#  'is',
#  'the',
#  'damage',
#  'that',
#  'these',
#  'restrictions',
#  'are',
#  'causing',
#  'to',
#  'families',
#  ',',
#  'the',
#  'travel',
#  'and',
#  'tourism',
#  'industries',
#  'and',
#  'business',
#  ',',
#  "''",
#  'south',
#  'african',
#  'foreign',
#  'minister',
#  'naledi',
#  'pandor',
#  'said',
#  'in',
#  'the',
#  'statement',
#  '.',
#  'the',
#  'government',
#  'was',
#  'engaging',
#  'with',
#  'countries',
#  'that',
#  'have',
#  'imposed',
#  'travel',
#  'bans',
#  'to',
#  'persuade',
#  'them',
#  'to',
#  'reconsider',
#  ',',
#  'it',
#  'added',
#  '.',
#  'on',
#  'friday',
#  ',',
#  'the',
#  'who',
#  'cautioned',
#  'countries',
#  'against',
#  'hastily',
#  'imposing',
#  'travel',
#  'restrictions',
#  'linked',
#  'to',
#  'the',
#  'variant',
#  ',',
#  'saying',
#  'they',
#  'should',
#  'take',
#  'a',
#  '``',
#  'risk-based',
#  'and',
#  'scientific',
#  'approach',
#  "''",
#  '.']

# %%
freq_dist_words = nltk.FreqDist(word_tokens)
freq_dist_words
# Out:
# FreqDist({"''": 7,
#           "'s": 2,
#           '(': 1,
#           ')': 1,
#           ',': 13,
#           '-': 3,
#           '.': 12,
#           '27': 1,
#           '``': 5,
#           'a': 5,
#           'ability': 2,
#           'added': 1,
#           'advanced': 2,
#           'africa': 7,
#           'african': 1,
#           'against': 1,
#           'akin': 1,
#           'also': 1,
#           'an': 1,
#           'and': 16,
#           'announce': 1,
#           'announced': 1,
#           'applauded': 1,
#           'approach': 1,
#           'are': 1,
#           'as': 2,
#           'bans': 3,
#           'be': 1,
#           'because': 1,
#           'been': 2,
#           'being': 1,
#           'belgium': 1,
#           'body': 1,
#           'botswana': 1,
#           'business': 1,
#           'by': 1,
#           'cases': 1,
#           'causing': 1,
#           'cautioned': 1,
#           'concern': 2,
#           'cooperation': 1,
#           'coronavirus': 1,
#           'could': 1,
#           'countries': 5,
#           'covid-19': 1,
#           'curbs': 1,
#           'cycle': 1,
#           'damage': 1,
#           'designated': 1,
#           'detect': 3,
#           'detected': 3,
#           'different': 1,
#           'discovered': 1,
#           'early': 2,
#           'economy': 1,
#           'emerging': 1,
#           'engaging': 1,
#           'epidemiologists': 1,
#           'evade': 1,
#           'evidence': 1,
#           'excellent': 1,
#           'families': 1,
#           'first': 2,
#           'for': 2,
#           'foreign': 2,
#           'friday': 3,
#           'genomic': 1,
#           'global': 1,
#           'government': 1,
#           'had': 1,
#           'harm': 1,
#           'has': 2,
#           'hastily': 1,
#           'have': 3,
#           'health': 1,
#           'hong': 1,
#           'immediate': 1,
#           'immune': 1,
#           'imposed': 2,
#           'imposing': 1,
#           'in': 9,
#           'increased': 1,
#           'industries': 1,
#           'international': 1,
#           'is': 2,
#           'israel': 1,
#           'it': 6,
#           'its': 3,
#           'johannesburg': 1,
#           'kong': 1,
#           'latest': 1,
#           'level': 1,
#           'life': 1,
#           'linked': 1,
#           'make': 1,
#           'managed': 1,
#           'many': 1,
#           'minister': 1,
#           'ministry': 2,
#           'more': 2,
#           'most': 1,
#           'mutations': 1,
#           'naledi': 1,
#           'named': 1,
#           'nations': 1,
#           'new': 5,
#           'not': 1,
#           'noted': 1,
#           'nov': 1,
#           'of': 8,
#           'omicron': 3,
#           'on': 6,
#           'organization': 1,
#           'other': 3,
#           'our': 1,
#           'pandor': 1,
#           'persuade': 1,
#           'possibly': 1,
#           'preliminary': 1,
#           'punished': 2,
#           'punishing': 1,
#           'quicker': 1,
#           're-infection': 1,
#           'reaction': 1,
#           'read': 1,
#           'reconsider': 1,
#           'region': 1,
#           'relations': 1,
#           'response': 1,
#           'restrictions': 3,
#           'reuters': 1,
#           'risk': 1,
#           'risk-based': 1,
#           'round': 1,
#           'rushed': 1,
#           'said': 5,
#           'saturday': 2,
#           'saying': 2,
#           'science': 1,
#           'scientific': 1,
#           'scientists': 2,
#           'sectors': 1,
#           'sequencing': 1,
#           'serious': 1,
#           'should': 2,
#           'since': 1,
#           'some': 1,
#           'south': 7,
#           'southern': 1,
#           'starkly': 1,
#           'statement': 2,
#           'suggests': 1,
#           'take': 1,
#           'team': 1,
#           'that': 4,
#           'the': 19,
#           'their': 2,
#           'them': 1,
#           'these': 1,
#           'they': 2,
#           'this': 1,
#           'those': 1,
#           'threaten': 1,
#           'to': 13,
#           'top': 1,
#           'tourism': 2,
#           'transmissible': 1,
#           'travel': 6,
#           'variant': 7,
#           'variants': 3,
#           'was': 5,
#           'wednesday': 1,
#           'while': 1,
#           'who': 3,
#           'with': 1,
#           'world': 2})

# %%
df_freq = pd.DataFrame.from_dict(freq_dist_words, orient='index', columns=['Frequency']).reset_index()
df_freq.sort_values('Frequency', ascending=False, inplace=True)
top_20_words = df_freq.head(20)
top_20_words = top_20_words.rename(columns={'index': 'Word'})

# %%
fig = px.bar(top_20_words, x='Word', y='Frequency', color='Frequency')

fig.update_layout(height=800, width=1200, template='plotly_dark', title='Distribution of Top 20 Words From Article')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="c10a8269-7e39-408f-81a5-c610af275e9a" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c10a8269-7e39-408f-81a5-c610af275e9a")) {                    Plotly.newPlot(                        "c10a8269-7e39-408f-81a5-c610af275e9a",                        [{"alignmentgroup":"True","hovertemplate":"Word=%{x}<br>Frequency=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[19,16,13,13,12,9,8,7,7,7,7,6,6,6,5,5,5,5,5,5],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["the","and","to",",",".","in","of","''","variant","south","africa","travel","on","it","new","was","``","said","a","countries"],"xaxis":"x","y":[19,16,13,13,12,9,8,7,7,7,7,6,6,6,5,5,5,5,5,5],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colo ...

# %% [markdown]
# ## Stopwords Removal

# %%
word_tokens_clean = []
my_punct = ["''", "``", '""', "'s", '-']

for word in word_tokens:
  if word not in nltk.corpus.stopwords.words('english'):
    if word not in string.punctuation:
      if word not in my_punct:
        word_tokens_clean.append(word)

print(word_tokens_clean)
# Out:
# ['johannesburg', 'nov', '27', 'reuters', 'south', 'africa', 'said', 'saturday', 'punished', 'advanced', 'ability', 'detect', 'new', 'covid-19', 'variants', 'early', 'travel', 'bans', 'restrictions', 'imposed', 'new', 'omicron', 'variant', 'threaten', 'harm', 'tourism', 'sectors', 'economy', 'south', 'africa', 'world', 'top', 'epidemiologists', 'scientists', 'managed', 'detect', 'emerging', 'coronavirus', 'variants', 'mutations', 'early', 'life', 'cycle', 'omicron', 'variant', 'first', 'discovered', 'south', 'africa', 'since', 'detected', 'belgium', 'botswana', 'israel', 'hong', 'kong', 'latest', 'round', 'travel', 'bans', 'akin', 'punishing', 'south', 'africa', 'advanced', 'genomic', 'sequencing', 'ability', 'detect', 'new', 'variants', 'quicker', 'ministry', 'international', 'relations', 'cooperation', 'said', 'excellent', 'science', 'applauded', 'punished', 'said', 'statement', 'many', 'nations', 'rushed', 'friday', 'saturday', 'announce', 'travel', 'curbs', 'south', 'africa', 'countries', 'region', 'foreign', 'ministry', 'noted', 'new', 'variant', 'also', 'detected', 'countries', 'global', 'reaction', 'countries', 'starkly', 'different', 'cases', 'southern', 'africa', 'new', 'variant', 'first', 'announced', 'wednesday', 'team', 'scientists', 'south', 'africa', 'said', 'detected', 'variant', 'could', 'possibly', 'evade', 'body', 'immune', 'response', 'make', 'transmissible', 'friday', 'world', 'health', 'organization', 'named', 'omicron', 'designated', 'variant', 'concern', 'serious', 'level', 'saying', 'preliminary', 'evidence', 'suggests', 'increased', 'risk', 're-infection', 'read', 'immediate', 'concern', 'damage', 'restrictions', 'causing', 'families', 'travel', 'tourism', 'industries', 'business', 'south', 'african', 'foreign', 'minister', 'naledi', 'pandor', 'said', 'statement', 'government', 'engaging', 'countries', 'imposed', 'travel', 'bans', 'persuade', 'reconsider', 'added', 'friday', 'cautioned', 'countries', 'hastily', 'imposing', 'travel', 'restrictions', 'linked', 'variant', 'saying', 'take', 'risk-based', 'scientific', 'approach']

# %%
freq_dist_words_clean = nltk.FreqDist(word_tokens_clean)

# %%
df_freq_clean = pd.DataFrame.from_dict(freq_dist_words_clean, orient='index', columns=['Frequency']).reset_index()
df_freq_clean.sort_values('Frequency', ascending=False, inplace=True)
top_20_words_clean = df_freq_clean.head(20)
top_20_words_clean = top_20_words_clean.rename(columns={'index': 'Word'})

# %%
fig = px.bar(top_20_words_clean, x='Word', y='Frequency', color='Frequency')

fig.update_layout(height=800, width=1200, template='plotly_dark', title='Distribution of Top 20 Words From Article')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="36c5314d-311e-4224-a0b4-d4d6af123b8f" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36c5314d-311e-4224-a0b4-d4d6af123b8f")) {                    Plotly.newPlot(                        "36c5314d-311e-4224-a0b4-d4d6af123b8f",                        [{"alignmentgroup":"True","hovertemplate":"Word=%{x}<br>Frequency=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[7,7,7,6,5,5,5,3,3,3,3,3,3,3,2,2,2,2,2,2],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["variant","south","africa","travel","said","countries","new","bans","detect","variants","detected","omicron","friday","restrictions","world","foreign","scientists","concern","statement","tourism"],"xaxis":"x","y":[7,7,7,6,5,5,5,3,3,3,3,3,3,3,2,2,2,2,2,2],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth" ...

# %% [markdown]
# ## Stemming

# %%
stem_en = nltk.stem.SnowballStemmer("english")

# %%
stemmed_words = [stem_en.stem(word) for word in word_tokens_clean]
stemmed_words
# Out:
# ['johannesburg',
#  'nov',
#  '27',
#  'reuter',
#  'south',
#  'africa',
#  'said',
#  'saturday',
#  'punish',
#  'advanc',
#  'abil',
#  'detect',
#  'new',
#  'covid-19',
#  'variant',
#  'earli',
#  'travel',
#  'ban',
#  'restrict',
#  'impos',
#  'new',
#  'omicron',
#  'variant',
#  'threaten',
#  'harm',
#  'tourism',
#  'sector',
#  'economi',
#  'south',
#  'africa',
#  'world',
#  'top',
#  'epidemiologist',
#  'scientist',
#  'manag',
#  'detect',
#  'emerg',
#  'coronavirus',
#  'variant',
#  'mutat',
#  'earli',
#  'life',
#  'cycl',
#  'omicron',
#  'variant',
#  'first',
#  'discov',
#  'south',
#  'africa',
#  'sinc',
#  'detect',
#  'belgium',
#  'botswana',
#  'israel',
#  'hong',
#  'kong',
#  'latest',
#  'round',
#  'travel',
#  'ban',
#  'akin',
#  'punish',
#  'south',
#  'africa',
#  'advanc',
#  'genom',
#  'sequenc',
#  'abil',
#  'detect',
#  'new',
#  'variant',
#  'quicker',
#  'ministri',
#  'intern',
#  'relat',
#  'cooper',
#  'said',
#  'excel',
#  'scienc',
#  'applaud',
#  'punish',
#  'said',
#  'statement',
#  'mani',
#  'nation',
#  'rush',
#  'friday',
#  'saturday',
#  'announc',
#  'travel',
#  'curb',
#  'south',
#  'africa',
#  'countri',
#  'region',
#  'foreign',
#  'ministri',
#  'note',
#  'new',
#  'variant',
#  'also',
#  'detect',
#  'countri',
#  'global',
#  'reaction',
#  'countri',
#  'stark',
#  'differ',
#  'case',
#  'southern',
#  'africa',
#  'new',
#  'variant',
#  'first',
#  'announc',
#  'wednesday',
#  'team',
#  'scientist',
#  'south',
#  'africa',
#  'said',
#  'detect',
#  'variant',
#  'could',
#  'possibl',
#  'evad',
#  'bodi',
#  'immun',
#  'respons',
#  'make',
#  'transmiss',
#  'friday',
#  'world',
#  'health',
#  'organ',
#  'name',
#  'omicron',
#  'design',
#  'variant',
#  'concern',
#  'serious',
#  'level',
#  'say',
#  'preliminari',
#  'evid',
#  'suggest',
#  'increas',
#  'risk',
#  're-infect',
#  'read',
#  'immedi',
#  'concern',
#  'damag',
#  'restrict',
#  'caus',
#  'famili',
#  'travel',
#  'tourism',
#  'industri',
#  'busi',
#  'south',
#  'african',
#  'foreign',
#  'minist',
#  'naledi',
#  'pandor',
#  'said',
#  'statement',
#  'govern',
#  'engag',
#  'countri',
#  'impos',
#  'travel',
#  'ban',
#  'persuad',
#  'reconsid',
#  'ad',
#  'friday',
#  'caution',
#  'countri',
#  'hastili',
#  'impos',
#  'travel',
#  'restrict',
#  'link',
#  'variant',
#  'say',
#  'take',
#  'risk-bas',
#  'scientif',
#  'approach']

# %%
freq_dist_words_stem = nltk.FreqDist(stemmed_words)
freq_dist_words_stem
# Out:
# FreqDist({'27': 1,
#           'abil': 2,
#           'ad': 1,
#           'advanc': 2,
#           'africa': 7,
#           'african': 1,
#           'akin': 1,
#           'also': 1,
#           'announc': 2,
#           'applaud': 1,
#           'approach': 1,
#           'ban': 3,
#           'belgium': 1,
#           'bodi': 1,
#           'botswana': 1,
#           'busi': 1,
#           'case': 1,
#           'caus': 1,
#           'caution': 1,
#           'concern': 2,
#           'cooper': 1,
#           'coronavirus': 1,
#           'could': 1,
#           'countri': 5,
#           'covid-19': 1,
#           'curb': 1,
#           'cycl': 1,
#           'damag': 1,
#           'design': 1,
#           'detect': 6,
#           'differ': 1,
#           'discov': 1,
#           'earli': 2,
#           'economi': 1,
#           'emerg': 1,
#           'engag': 1,
#           'epidemiologist': 1,
#           'evad': 1,
#           'evid': 1,
#           'excel': 1,
#           'famili': 1,
#           'first': 2,
#           'foreign': 2,
#           'friday': 3,
#           'genom': 1,
#           'global': 1,
#           'govern': 1,
#           'harm': 1,
#           'hastili': 1,
#           'health': 1,
#           'hong': 1,
#           'immedi': 1,
#           'immun': 1,
#           'impos': 3,
#           'increas': 1,
#           'industri': 1,
#           'intern': 1,
#           'israel': 1,
#           'johannesburg': 1,
#           'kong': 1,
#           'latest': 1,
#           'level': 1,
#           'life': 1,
#           'link': 1,
#           'make': 1,
#           'manag': 1,
#           'mani': 1,
#           'minist': 1,
#           'ministri': 2,
#           'mutat': 1,
#           'naledi': 1,
#           'name': 1,
#           'nation': 1,
#           'new': 5,
#           'note': 1,
#           'nov': 1,
#           'omicron': 3,
#           'organ': 1,
#           'pandor': 1,
#           'persuad': 1,
#           'possibl': 1,
#           'preliminari': 1,
#           'punish': 3,
#           'quicker': 1,
#           're-infect': 1,
#           'reaction': 1,
#           'read': 1,
#           'reconsid': 1,
#           'region': 1,
#           'relat': 1,
#           'respons': 1,
#           'restrict': 3,
#           'reuter': 1,
#           'risk': 1,
#           'risk-bas': 1,
#           'round': 1,
#           'rush': 1,
#           'said': 5,
#           'saturday': 2,
#           'say': 2,
#           'scienc': 1,
#           'scientif': 1,
#           'scientist': 2,
#           'sector': 1,
#           'sequenc': 1,
#           'serious': 1,
#           'sinc': 1,
#           'south': 7,
#           'southern': 1,
#           'stark': 1,
#           'statement': 2,
#           'suggest': 1,
#           'take': 1,
#           'team': 1,
#           'threaten': 1,
#           'top': 1,
#           'tourism': 2,
#           'transmiss': 1,
#           'travel': 6,
#           'variant': 10,
#           'wednesday': 1,
#           'world': 2})

# %%
df_freq_stem = pd.DataFrame.from_dict(freq_dist_words_stem, orient='index', columns=['Frequency']).reset_index()
df_freq_stem.sort_values('Frequency', ascending=False, inplace=True)
top_20_words_stem = df_freq_stem.head(20)
top_20_words_stem = top_20_words_stem.rename(columns={'index': 'Word'})

# %%
fig = px.bar(top_20_words_stem, x='Word', y='Frequency', color='Frequency')

fig.update_layout(height=800, width=1200, template='plotly_dark', title='Distribution of Top 20 Words From Article (stemmed)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="84bf69b5-4089-4850-9c16-1c1fa6aadbf8" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84bf69b5-4089-4850-9c16-1c1fa6aadbf8")) {                    Plotly.newPlot(                        "84bf69b5-4089-4850-9c16-1c1fa6aadbf8",                        [{"alignmentgroup":"True","hovertemplate":"Word=%{x}<br>Frequency=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[10,7,7,6,6,5,5,5,3,3,3,3,3,3,2,2,2,2,2,2],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["variant","south","africa","detect","travel","new","countri","said","omicron","impos","restrict","ban","friday","punish","say","tourism","ministri","concern","statement","announc"],"xaxis":"x","y":[10,7,7,6,6,5,5,5,3,3,3,3,3,3,2,2,2,2,2,2],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""} ...

# %% [markdown]
# ## Lemmatizing

# %%
nlp = spacy.load("en_core_web_sm")

string_words = ' '.join([str(word) for word in word_tokens_clean])
nlp_tokens = nlp(string_words)

word_tokens_lemma = [word.lemma_ for word in nlp_tokens]
word_tokens_lemma
# Out:
# ['johannesburg',
#  'nov',
#  '27',
#  'reuters',
#  'south',
#  'africa',
#  'say',
#  'saturday',
#  'punish',
#  'advanced',
#  'ability',
#  'detect',
#  'new',
#  'covid-19',
#  'variant',
#  'early',
#  'travel',
#  'ban',
#  'restriction',
#  'impose',
#  'new',
#  'omicron',
#  'variant',
#  'threaten',
#  'harm',
#  'tourism',
#  'sector',
#  'economy',
#  'south',
#  'africa',
#  'world',
#  'top',
#  'epidemiologist',
#  'scientist',
#  'manage',
#  'detect',
#  'emerge',
#  'coronavirus',
#  'variant',
#  'mutation',
#  'early',
#  'life',
#  'cycle',
#  'omicron',
#  'variant',
#  'first',
#  'discover',
#  'south',
#  'africa',
#  'since',
#  'detect',
#  'belgium',
#  'botswana',
#  'israel',
#  'hong',
#  'kong',
#  'late',
#  'round',
#  'travel',
#  'ban',
#  'akin',
#  'punish',
#  'south',
#  'africa',
#  'advance',
#  'genomic',
#  'sequencing',
#  'ability',
#  'detect',
#  'new',
#  'variant',
#  'quick',
#  'ministry',
#  'international',
#  'relations',
#  'cooperation',
#  'say',
#  'excellent',
#  'science',
#  'applaud',
#  'punish',
#  'say',
#  'statement',
#  'many',
#  'nation',
#  'rush',
#  'friday',
#  'saturday',
#  'announce',
#  'travel',
#  'curbs',
#  'south',
#  'africa',
#  'country',
#  'region',
#  'foreign',
#  'ministry',
#  'note',
#  'new',
#  'variant',
#  'also',
#  'detect',
#  'country',
#  'global',
#  'reaction',
#  'country',
#  'starkly',
#  'different',
#  'case',
#  'southern',
#  'africa',
#  'new',
#  'variant',
#  'first',
#  'announce',
#  'wednesday',
#  'team',
#  'scientist',
#  'south',
#  'africa',
#  'say',
#  'detect',
#  'variant',
#  'could',
#  'possibly',
#  'evade',
#  'body',
#  'immune',
#  'response',
#  'make',
#  'transmissible',
#  'friday',
#  'world',
#  'health',
#  'organization',
#  'name',
#  'omicron',
#  'designate',
#  'variant',
#  'concern',
#  'serious',
#  'level',
#  'say',
#  'preliminary',
#  'evidence',
#  'suggest',
#  'increase',
#  'risk',
#  're',
#  '-',
#  'infection',
#  'read',
#  'immediate',
#  'concern',
#  'damage',
#  'restriction',
#  'cause',
#  'family',
#  'travel',
#  'tourism',
#  'industry',
#  'business',
#  'south',
#  'african',
#  'foreign',
#  'minister',
#  'naledi',
#  'pandor',
#  'say',
#  'statement',
#  'government',
#  'engage',
#  'country',
#  'impose',
#  'travel',
#  'ban',
#  'persuade',
#  'reconsider',
#  'add',
#  'friday',
#  'caution',
#  'country',
#  'hastily',
#  'impose',
#  'travel',
#  'restriction',
#  'link',
#  'variant',
#  'say',
#  'take',
#  'risk',
#  '-',
#  'base',
#  'scientific',
#  'approach']

# %%
# Looks like some punctuation came back, let's get rid of it again

word_tokens_lemma_2 = []

for word in word_tokens_lemma:
  if word not in string.punctuation:
    word_tokens_lemma_2.append(word)

# %%
freq_dist_words_lemm = nltk.FreqDist(word_tokens_lemma_2)
freq_dist_words_lemm
# Out:
# FreqDist({'27': 1,
#           'ability': 2,
#           'add': 1,
#           'advance': 1,
#           'advanced': 1,
#           'africa': 7,
#           'african': 1,
#           'akin': 1,
#           'also': 1,
#           'announce': 2,
#           'applaud': 1,
#           'approach': 1,
#           'ban': 3,
#           'base': 1,
#           'belgium': 1,
#           'body': 1,
#           'botswana': 1,
#           'business': 1,
#           'case': 1,
#           'cause': 1,
#           'caution': 1,
#           'concern': 2,
#           'cooperation': 1,
#           'coronavirus': 1,
#           'could': 1,
#           'country': 5,
#           'covid-19': 1,
#           'curbs': 1,
#           'cycle': 1,
#           'damage': 1,
#           'designate': 1,
#           'detect': 6,
#           'different': 1,
#           'discover': 1,
#           'early': 2,
#           'economy': 1,
#           'emerge': 1,
#           'engage': 1,
#           'epidemiologist': 1,
#           'evade': 1,
#           'evidence': 1,
#           'excellent': 1,
#           'family': 1,
#           'first': 2,
#           'foreign': 2,
#           'friday': 3,
#           'genomic': 1,
#           'global': 1,
#           'government': 1,
#           'harm': 1,
#           'hastily': 1,
#           'health': 1,
#           'hong': 1,
#           'immediate': 1,
#           'immune': 1,
#           'impose': 3,
#           'increase': 1,
#           'industry': 1,
#           'infection': 1,
#           'international': 1,
#           'israel': 1,
#           'johannesburg': 1,
#           'kong': 1,
#           'late': 1,
#           'level': 1,
#           'life': 1,
#           'link': 1,
#           'make': 1,
#           'manage': 1,
#           'many': 1,
#           'minister': 1,
#           'ministry': 2,
#           'mutation': 1,
#           'naledi': 1,
#           'name': 1,
#           'nation': 1,
#           'new': 5,
#           'note': 1,
#           'nov': 1,
#           'omicron': 3,
#           'organization': 1,
#           'pandor': 1,
#           'persuade': 1,
#           'possibly': 1,
#           'preliminary': 1,
#           'punish': 3,
#           'quick': 1,
#           're': 1,
#           'reaction': 1,
#           'read': 1,
#           'reconsider': 1,
#           'region': 1,
#           'relations': 1,
#           'response': 1,
#           'restriction': 3,
#           'reuters': 1,
#           'risk': 2,
#           'round': 1,
#           'rush': 1,
#           'saturday': 2,
#           'say': 7,
#           'science': 1,
#           'scientific': 1,
#           'scientist': 2,
#           'sector': 1,
#           'sequencing': 1,
#           'serious': 1,
#           'since': 1,
#           'south': 7,
#           'southern': 1,
#           'starkly': 1,
#           'statement': 2,
#           'suggest': 1,
#           'take': 1,
#           'team': 1,
#           'threaten': 1,
#           'top': 1,
#           'tourism': 2,
#           'transmissible': 1,
#           'travel': 6,
#           'variant': 10,
#           'wednesday': 1,
#           'world': 2})

# %%
df_freq_lemm = pd.DataFrame.from_dict(freq_dist_words_lemm, orient='index', columns=['Frequency']).reset_index()
df_freq_lemm.sort_values('Frequency', ascending=False, inplace=True)
top_20_words_lemm = df_freq_lemm.head(20)
top_20_words_lemm = top_20_words_lemm.rename(columns={'index': 'Word'})

# %%
# Putting 2 charts next to each other to compare

fig = px.bar(top_20_words_stem, x='Word', y='Frequency', color='Frequency', labels={'Word': 'Stemmed Words'})

fig.update_layout(height=450, width=1100, template='plotly_dark', title='Distribution of Top 20 Words From Article (stemmed)')
fig.show()

fig = px.bar(top_20_words_lemm, x='Word', y='Frequency', color='Frequency', labels={'Word': 'Lemmatized Words'})

fig.update_layout(height=450, width=1100, template='plotly_dark', title='Distribution of Top 20 Words From Article (lemmatized)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="a2e5fa3f-025e-452d-aeda-6de0d9507ee6" class="plotly-graph-div" style="height:450px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2e5fa3f-025e-452d-aeda-6de0d9507ee6")) {                    Plotly.newPlot(                        "a2e5fa3f-025e-452d-aeda-6de0d9507ee6",                        [{"alignmentgroup":"True","hovertemplate":"Stemmed Words=%{x}<br>Frequency=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[10,7,7,6,6,5,5,5,3,3,3,3,3,3,2,2,2,2,2,2],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["variant","south","africa","detect","travel","new","countri","said","omicron","impos","restrict","ban","friday","punish","say","tourism","ministri","concern","statement","announc"],"xaxis":"x","y":[10,7,7,6,6,5,5,5,3,3,3,3,3,3,2,2,2,2,2,2],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"t ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.6.3.min.js"></script>                <div id="c1f5ac72-c3d1-415f-bb14-5a1274d915e7" class="plotly-graph-div" style="height:450px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c1f5ac72-c3d1-415f-bb14-5a1274d915e7")) {                    Plotly.newPlot(                        "c1f5ac72-c3d1-415f-bb14-5a1274d915e7",                        [{"alignmentgroup":"True","hovertemplate":"Lemmatized Words=%{x}<br>Frequency=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[10,7,7,7,6,6,5,5,3,3,3,3,3,3,2,2,2,2,2,2],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["variant","south","africa","say","detect","travel","country","new","ban","restriction","impose","omicron","punish","friday","announce","scientist","concern","foreign","first","world"],"xaxis":"x","y":[10,7,7,7,6,6,5,5,3,3,3,3,3,3,2,2,2,2,2,2],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth ...

# %% [markdown]
# Both frequency lists look roughly the same, some words are better captured in the lemmatized list (like the verb say, instead of say and said on two occurrences), but the overall distribution is comparable. We can note though that words are more readable in the lemmatized version, as they are actual words and not words missing some letters.
